# %% [markdown]
# ## KENYO PRESENTADO POR : INFA ESPEJO ISAIAS KENYO

# %% [markdown]
# ## MACHINE LEARNING - KMEANS

# %% [markdown]
# ## OPEN DATA

# %% [markdown]
# ### Librerías

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
wine=pd.read_csv("caracteristicas de vinos.csv")

# %%
wine.head()
# Out:
#    Vino  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     2    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     3    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     4    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     5    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
wine.isnull().sum()
# Out:
# Vino               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Vino             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
wine.isnull().sum()
# Out:
# Vino               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
wine.shape
# Out:
# (178, 14)

# %%
wine.dtypes
# Out:
# Vino                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
wine.describe().T
# Out:
#                  count        mean         std     min       25%      50%  \
# Vino             178.0   89.500000   51.528309    1.00   45.2500   89.500
# Alcohol          178.0   13.000618    0.811827   11.03   12.3625   13.050
# Malic            178.0    2.336348    1.117146    0.74    1.6025    1.865
# Ash              178.0    2.366517    0.274344    1.36    2.2100    2.360
# Alcalinity       178.0   19.494944    3.339564   10.60   17.2000   19.500
# Magnesium        178.0   99.741573   14.282484   70.00   88.0000   98.000
# Phenols          178.0    2.295112    0.625851    0.98    1.7425    2.355
# Flavanoids       178.0    2.029270    0.998859    0.34    1.2050    2.135
# Nonflavanoids    178.0    0.361854    0.124453    0.13    0.2700    0.340
# Proanthocyanins  178.0    1.590899    0.572359    0.41    1.2500    1.555
# Color            178.0    5.058090    2.318286    1.28    3.2200    4.690
# Hue              178.0    0.957449    0.228572    0.48    0.7825    0.965
# ...

# %%
wine.columns
# Out:
# Index(['Vino', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %% [markdown]
# ### Normalización

# %%
vino=wine

# %%
vino
# Out:
#      Vino  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       2    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       3    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       4    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       5    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173   174    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174   175    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175   176    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176   177    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177   178    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %% [markdown]
# ##  Cantidad de óptima de Cluster mediante el metodo del CODO DE JAMBU

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, max_iter=300)
    kmeans.fit(vino)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title("Codo de Jambú")
plt.xlabel("Numero de Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
clustering=KMeans(n_clusters=3, max_iter=300)
clustering.fit(vino)
# Out:
# KMeans(n_clusters=3)

# %%
vino["KMeans_cluster"]=clustering.labels_
vino.head()
# Out:
#    Vino  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     2    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     3    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     4    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     5    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  \
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735
#
#    KMeans_cluster
# 0               1
# 1               1
# 2               1
# 3               1
# 4               0

# %% [markdown]
# ## GRAFICAS

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca_vino=pca.fit_transform(vino)
pca_vino_df=pd.DataFrame(data=pca_vino,columns=["Component_1","Component_2"])
pca_nombre_vino=pd.concat([pca_vino_df,vino[["KMeans_cluster"]]],axis=1)
pca_nombre_vino.head(20)
# Out:
#     Component_1  Component_2  KMeans_cluster
# 0    326.174009   -53.857316               1
# 1    310.690618   -54.991784               1
# 2    444.780332   -39.378439               1
# 3    738.175008    -6.893100               1
# 4     -2.508952   -84.894433               0
# 5    708.123840    -8.183846               1
# 6    548.668980   -24.459129               1
# 7    553.961362   -22.504123               1
# 8    304.913458   -48.497862               1
# 9    304.819406   -47.373998               1
# 10   767.099935     3.108408               1
# 11   538.165226   -20.504422               1
# 12   577.723343   -15.355545               1
# 13   408.673756   -32.552521               1
# 14   803.437905    10.834929               1
# 15   567.869080   -13.029422               1
# 16   538.066220   -15.064863               1
# 17   388.750659   -30.061790               1
# 18   935.320378    29.189609               1
# 19   105.243985   -58.501926               0

# %%
fig=plt.figure(figsize=(7,7))
ax=fig.add_subplot(1,1,1)
ax.set_xlabel("Component_1")
ax.set_ylabel("Component_2")
ax.set_title("Componentes Principales")
color_theme=np.array(["black","yellow","pink"])
ax.scatter(x=pca_nombre_vino.Component_1,y=pca_nombre_vino.Component_2,
           c=color_theme[pca_nombre_vino.KMeans_cluster],s=50)
plt.show()
